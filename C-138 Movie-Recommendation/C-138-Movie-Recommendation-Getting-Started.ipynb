# %% [markdown]
# <a href="https://colab.research.google.com/github/sohanCoder308/138-144-Class-Activities-Sohan/blob/main/C-138%20Movie-Recommendation/C-138-Movie-Recommendation-Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This is Class Activity 138 - Movie Recommendation**
#
# **-Taught by Rekha Mam**
#
# **-Learned by Sohan**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a177c214-3a2e-4bfe-b6f8-70ba00cb084e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a177c214-3a2e-4bfe-b6f8-70ba00cb084e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"sohanscreation","key":"905b1393300c44030d61dcae51c1ad34"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
#   0% 0.00/8.89M [00:00<?, ?B/s]
# 100% 8.89M/8.89M [00:00<00:00, 81.8MB/s]

# %%
# !ls
# !unzip tmdb-movie-metadata.zip
# !ls
# Out:
# kaggle.json  tmdb_5000_credits.csv  tmdb-movie-metadata.zip
# sample_data  tmdb_5000_movies.csv
# Archive:  tmdb-movie-metadata.zip
# replace tmdb_5000_credits.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# kaggle.json  tmdb_5000_credits.csv  tmdb-movie-metadata.zip
# sample_data  tmdb_5000_movies.csv

# %%
import pandas as pd
import csv

df1 = pd.read_csv("tmdb_5000_credits.csv")
df2 = pd.read_csv("tmdb_5000_movies.csv")

df1.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
df2.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
df1.columns = ['id','title','cast','crew'] 
df2= df2.merge(df1,on='id')
df2.head(5)
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 41 columns]
